# %% [markdown]
# # Task 4: Playing Card Magic Trick with Quantum States
#
# **Starter Notebook**
#
# ## Learning Objectives
#
# - Represent classical objects as quantum states
# - Work with 32-dimensional Hilbert spaces
# - Apply tensor (Kronecker) products
# - Calculate probability amplitudes
# - Understand quantum measurement probabilities
#
# ## Instructions
#
# Complete each exercise by writing code in the provided cells. Use hints and refer to the README for guidance.
#
# ## Estimated Time: 45-60 minutes

# %%
# Google Colab Setup - Run this cell first if using Colab
import sys
if 'google.colab' in sys.modules:
    print("📦 Installing dependencies for Google Colab...")
    # !pip install -q numpy>=1.24.0 matplotlib seaborn
    print("✓ Dependencies installed successfully!")
    print("You can now run the rest of the notebook.\n")
else:
    print("✓ Running in local environment")

# %% [markdown]
# ## Setup and Imports

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Set random seed
np.random.seed(42)

# Configure matplotlib
style_path = Path('../../assets/styles/qcai_style.mplstyle')
if style_path.exists():
    plt.style.use(str(style_path))
else:
    plt.rcParams['figure.figsize'] = (12, 6)
    plt.rcParams['font.size'] = 12

print("Setup complete!")

# %% [markdown]
# ---
#
# ## Exercise 1: Define Rank Basis States
#
# ### Background
#
# Create 8 rank basis states (7, 8, 9, 10, J, Q, K, A) as column vectors in an 8-dimensional Hilbert space.
#
# ### Your Task
#
# Define each rank as an 8×1 column vector.
#
# **Hints:**
# - Use `np.array([[1], [0], ...])` for column vectors
# - |7⟩ has 1 in first position, 0s elsewhere
# - |8⟩ has 1 in second position, 0s elsewhere
# - etc.

# %%
# YOUR CODE HERE: Define rank basis states
# rank_7 = ?
# rank_8 = ?
# rank_9 = ?
# rank_10 = ?
# rank_J = ?
# rank_Q = ?
# rank_K = ?
# rank_A = ?

# ranks = [rank_7, rank_8, rank_9, rank_10, rank_J, rank_Q, rank_K, rank_A]
# rank_names = ['7', '8', '9', '10', 'J', 'Q', 'K', 'A']


# Verification
print("Rank basis states created:")
for name, rank in zip(rank_names, ranks):
    print(f"  |{name}⟩: shape {rank.shape}, norm {np.linalg.norm(rank):.1f}")

# %% [markdown]
# **Expected:** All ranks have shape (8, 1) and norm 1.0

# %% [markdown]
# ---
#
# ## Exercise 2: Define Suit Basis States
#
# ### Your Task
#
# Define 4 suit basis states (♠, ♥, ♦, ♣) as 4×1 column vectors.
#
# **Hints:**
# - Similar to ranks but 4D instead of 8D
# - Each suit has 1 in one position, 0s elsewhere

# %%
# YOUR CODE HERE: Define suit basis states
# spades = ?
# hearts = ?
# diamonds = ?
# clubs = ?

# suits = [spades, hearts, diamonds, clubs]
# suit_names = ['♠', '♥', '♦', '♣']


# Verification
print("Suit basis states created:")
for name, suit in zip(suit_names, suits):
    print(f"  |{name}⟩: shape {suit.shape}, norm {np.linalg.norm(suit):.1f}")

# %% [markdown]
# **Expected:** All suits have shape (4, 1) and norm 1.0

# %% [markdown]
# ---
#
# ## Exercise 3: Construct Card States
#
# ### Your Task
#
# Use Kronecker product to combine rank and suit into a complete card state.
#
# **Hints:**
# - Use `np.kron(rank, suit)`
# - Result will be 32×1 (8 × 4 = 32)

# %%
# YOUR CODE HERE: Construct card states
# Example: 7 of Spades
# card_7_spades = ?


# Verification
print(f"7 of Spades:")
print(f"  Shape: {card_7_spades.shape}")
print(f"  Norm: {np.linalg.norm(card_7_spades):.1f}")

# %% [markdown]
# **Expected:** Shape (32, 1), norm 1.0

# %% [markdown]
# ### Visualise Card State

# %%
# YOUR CODE HERE: Visualize card state
# Create bar plot of amplitudes
# plt.bar(...)
# plt.show()

# %% [markdown]
# ---
#
# ## Exercise 4: Create All 32 Cards
#
# ### Your Task
#
# Generate all 32 card states systematically.
#
# **Hints:**
# - Use nested loops: for each rank, for each suit
# - Store in a dictionary with card names as keys

# %%
# YOUR CODE HERE: Create all cards
# all_cards = {}
# all_card_names = []

# for rank_name, rank_state in zip(rank_names, ranks):
#     for suit_name, suit_state in zip(suit_names, suits):
#         card_name = ?
#         card_state = ?
#         all_cards[card_name] = card_state
#         all_card_names.append(card_name)


print(f"Created {len(all_cards)} card states")

# %% [markdown]
# **Expected:** 32 card states

# %% [markdown]
# ---
#
# ## Exercise 5: Calculate Inner Products
#
# ### Your Task
#
# Calculate inner products between different cards.
#
# **Hints:**
# - Inner product: `np.dot(card1.T.conj(), card2)`
# - Same cards should give 1
# - Different cards should give 0

# %%
# YOUR CODE HERE: Calculate inner products
# card1 = all_cards['7♠']
# card2 = all_cards['7♠']  # Same
# card3 = all_cards['A♥']  # Different

# inner_same = ?
# inner_diff = ?


print(f"⟨7♠|7♠⟩ = {inner_same[0,0]:.10f}")
print(f"⟨7♠|A♥⟩ = {inner_diff[0,0]:.10f}")

# %% [markdown]
# **Expected:** Same = 1.0, Different = 0.0

# %% [markdown]
# ---
#
# ## Exercise 6: Calculate Probabilities
#
# ### Your Task
#
# Calculate measurement probabilities: $P = |\langle\psi|\phi\rangle|^2$
#
# **Hints:**
# - Probability = absolute value squared of inner product
# - `np.abs(inner)**2`

# %%
# YOUR CODE HERE: Calculate probabilities
# system_state = all_cards['7♠']

# For each card, calculate probability
# probabilities = {}
# for card_name in all_card_names:
#     card_state = all_cards[card_name]
#     inner = ?
#     prob = ?
#     probabilities[card_name] = prob


# Show top probabilities
sorted_probs = sorted(probabilities.items(), key=lambda x: x[1], reverse=True)
for card, prob in sorted_probs[:5]:
    print(f"  P({card}) = {prob:.4f}")

# %% [markdown]
# **Expected:** P(7♠) = 1.0, all others = 0.0

# %% [markdown]
# ---
#
# ## Exercise 7: Create Superposition States
#
# ### Your Task
#
# Create an equal superposition of two cards.
#
# **Hints:**
# - Superposition: `(card1 + card2) / sqrt(2)`
# - Must normalize: divide by `np.sqrt(n)` where n = number of cards

# %%
# YOUR CODE HERE: Create superposition
# card_A = all_cards['7♠']
# card_B = all_cards['A♥']

# superposition = ?


print(f"Superposition norm: {np.linalg.norm(superposition):.10f}")

# %% [markdown]
# **Expected:** Norm = 1.0

# %% [markdown]
# ### Calculate Superposition Probabilities

# %%
# YOUR CODE HERE: Calculate probabilities for superposition
# prob_A = ?
# prob_B = ?


print(f"P(7♠) = {prob_A:.4f}")
print(f"P(A♥) = {prob_B:.4f}")

# %% [markdown]
# **Expected:** Both probabilities = 0.5

# %% [markdown]
# ---
#
# ## Exercise 8: Superposition of Multiple Cards
#
# ### Your Task
#
# Create superposition of all 4 Aces.
#
# **Hint:** Normalization factor is `1/sqrt(4) = 1/2`

# %%
# YOUR CODE HERE: Superposition of Aces
# superposition_aces = (
#     all_cards['A♠'] + 
#     all_cards['A♥'] + 
#     all_cards['A♦'] + 
#     all_cards['A♣']
# ) / ?


print(f"Norm: {np.linalg.norm(superposition_aces):.10f}")

# %% [markdown]
# **Expected:** Norm = 1.0, each Ace probability = 0.25

# %% [markdown]
# ---
#
# ## Exercise 9: The Magic Trick
#
# ### Your Task
#
# Implement the magic trick function.
#
# **Hint:** Calculate probability of target card in given superposition

# %%
# YOUR CODE HERE: Magic trick function
# def magic_trick(target_card_name, superposition_cards):
#     # Create superposition
#     n = len(superposition_cards)
#     superposition = ?
#     
#     # Get target
#     target = all_cards[target_card_name]
#     
#     # Calculate probability
#     prob = ?
#     
#     return prob

# Test it
# prob = magic_trick('A♥', ['A♠', 'A♥', 'A♦', 'A♣'])
# print(f"Probability: {prob:.4f}")

# %% [markdown]
# **Expected:** Probability = 0.25 (for 4-card superposition)

# %% [markdown]
# ---
#
# ## Exercise 10: Visualization
#
# ### Your Task
#
# Create visualization of probability distribution.
#
# **Hint:** Calculate probabilities for all cards, plot as bar chart

# %%
# YOUR CODE HERE: Visualize probability distribution
# Create superposition of face cards
# Calculate probabilities for all cards
# Create bar plot

# %% [markdown]
# ---
#
# ## Summary
#
# ### Key Concepts Learned
#
# ✅ **Quantum State Representation**
#
# ✅ **Tensor Products**
#
# ✅ **Inner Products**
#
# ✅ **Superposition**
#
# ✅ **Quantum Probability**
#
# ### Next Steps
#
# 1. Compare with `task_04_solution.ipynb`
# 2. Run tests: `pytest tests/test_task_04.py`
# 3. Proceed to Task 5 (Quantum Error Correction)
#
# **Congratulations!** You've learned quantum probability! 🎉
